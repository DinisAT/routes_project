# %% [markdown]
# # Setup

# %% [markdown]
# Note: `Run this cell 2 times`

# %%
# !pip install --quiet openai==1.59.3
# !pip install --quiet langchain==0.3.14
# !pip install --quiet pypdf==5.1.0
# !pip install --quiet chromadb==0.4.22
# # !pip install --quiet tiktoken==0.5.2
# !pip show huggingface-hub
# !pip install --quiet diffusers==0.25.0
# !pip install --quiet google-api-python-client
# !pip install --quiet langchain_community
# !pip install --quiet langchain_openai
# !pip install --quiet pymupdf
# !pip install --quiet fitz
# !pip install --quiet langchain_experimental
# !pip install --quiet llama_index
# !pip install --quiet spacy
# !python -m spacy download en_core_web_sm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.4 MB/s eta 0:00:00

# %%
 # Initialize the OpenAI API client and set your API key
import os
import openai
import numpy as np
import pandas as pd
import json
